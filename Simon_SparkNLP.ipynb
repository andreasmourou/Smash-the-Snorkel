# %%
#Hey I've added this so we can see properly SQL Views from Spark (Simon)
from IPython.core.display import HTML
display(HTML("<style>pre { white-space: pre !important; }</style>"))
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# Out:
# <style>pre { white-space: pre !important; }</style>

# %%
# Import Spark NLP   
#from sparknlp import DocumentAssembler
import sparknlp
from sparknlp.base import *
from sparknlp.annotator import *
from sparknlp.embeddings import *
from sparknlp.base import DocumentAssembler, Finisher
from sparknlp.pretrained import PretrainedPipeline
from sparknlp.common import RegexRule

# Start Spark Session with Spark NLP
spark = sparknlp.start()
print("Spark NLP version: ", sparknlp.version())
print("Apache Spark version: ", spark.version)
# Out:
# Spark NLP version:  2.4.1
# Apache Spark version:  2.4.4

# %%
#Imports
import sys

import pyspark
from pyspark.sql import SparkSession
from pyspark.ml import Pipeline
from pyspark.sql.functions import array_contains
from pyspark.ml import Pipeline, PipelineModel

from pyspark.sql import functions as F
from pyspark.sql import SQLContext
sc = pyspark.SparkContext.getOrCreate()
sqlContext = SQLContext(sc)

# %%
df_dev = spark.read.csv("/project/review_dev_labelled.csv", escape='"', multiLine=True,
     inferSchema=True, header=True)

df_dev = df_dev.withColumnRenamed("label\r", "label")
df_dev.show()
# Out:
# +---+--------------------+----+----------------+-----+--------------------+-----+--------------------+------+--------------------+-------------+-------+-----+
# |  #|         business_id|cool|            date|funny|           review_id|stars|                text|useful|             user_id|      index_1|index_2|label|
# +---+--------------------+----+----------------+-----+--------------------+-----+--------------------+------+--------------------+-------------+-------+-----+
# |  0|XFhnPpO2x0nS-lVkq...|   1|14/02/2017 16:50|    0|o6VZ0cQEfIBvGW15u...|    2|I knew it was a k...|     0|dk5yqirSwDH7Cpp52...|1080000000000|      0|  1.0|
# |  1|SRCepG6PbMvwKcfIU...|   0|11/12/2015 02:47|    0|PBy3gB_D1xEiBJDrw...|    2|Average place, bu...|     0|xmtWxX67wF7afssQR...| 730000000000|      1|  1.0|
# |  2|pneBBrIzd3SCbbglY...|   2|15/05/2015 19:18|    0|AeyK7AEtbfubw1aD0...|    4|This is a great o...|     4|X4k8ugJaihHVLHq32...| 490000000000|      2|  0.0|
# |  3|8enR8Wc0ot9L41JY1...|   0|15/09/2017 13:17|    0|Vkx4AUppu9A7DL3AI...|    5|We took shelter a...|     0|Xpl0z24sZ-zJ6klgV...|1150000000000|      3|  0.0|
# |  4|HhVmDybpU7L50Kb5A...|   0|06/02/2016 02:12|    0|2GtcaGkq5nAxBvKZp...|    3|Had the burgers o...|     0|9T39fu4au232kl25R...| 996000000000|      4|  1.0|
# |  5|LUDX--wfStrKavGyi...|   1|17/07/2012 02:00|    0|yWy_rfgk40HuFs-HT...|    4|3 words...Twice B...|     2|yZS81ytT4TnAzaQ9Q...| 180000000000|      5|  0.0|
# |  6|AED5R0yXVzJvWAGEq...|   0|16/09/2016 18:48|    0|FH1vAWqpHTrrx1TCr...|    4|Be honest, my fir...|     1|8C8Ml7hj1zxyhcChk...| 524000000000|      6|  0.0|
# |  7|cxsN3mkioAXuOLKy0...|   1|15/09/2018 00:13|    1|LXuuEkxw1cE7R6QCQ...|    2|Read a meme today...|     2|DPitNu466172os6m0...|1030000000000|      7|  1.0|
# |  8|vfwTrfrZ3FWhVkyLj...|   0|14/12/2011 15:15|    0|wAIX_9diI4-oInUfp...|    5|Fish and chips fo...|     3|CeaQiG0KteHAnhKgb...|1560000000000|      8|  0.0|
# |  9|dsYjWjV0vr1RgSJ78...|   0|30/10/2011 13:40|    0|GYJBxUauqyMCgNVYL...|    4|We had dinner at ...|     0|TdYJqGeNjI-BmgXHQ...|  77309421985|      9|  0.0|
# | 10|Jm_R0IhwFlfCAV3Fk...|   0|10/11/2018 00:56|    0|B0jPms8H691N9jfEA...|    5|Came based on fam...|     0|IYpocDjXsAtL9B6XY...|1680000000000|     10|  0.0|
# | 11|WFB1fn8rWNukmmIfT...|   0|02/05/2018 18:31|    0|dqifjIBD_gkSaR6C8...|    5|We had a great ti...|     0|73Zav8SgUJN549GB8...| 137000000000|     11|  0.0|
# | 12|qQXc9D6PV1Y8RhIBZ...|   0|23/02/2018 18:16|    0|5HH9cZO5KiRwvD2IZ...|    5|I'm so glad I fou...|     0|XBvqoM6BaeAA-zdpB...| 215000000000|     12|  0.0|
# | 13|xiWmyJyTa7o1H6uUN...|   0|07/08/2017 15:28|    0|3baO5ezFrGdMxq2ZO...|    4|We went to the Ch...|     0|WEE4qvqumaw2EdkuE...| 515000000000|     13|  1.0|
# | 14|ZAuAwz1ijuydn5yL3...|   0|12/12/2016 06:09|    0|7KA11lzO6jAUWpSdK...|    4|One of my go to p...|     0|HN-2o_s91nULyyIBa...| 112000000000|     14|  1.0|
# | 15|TT2bNjvnVNFOanDNY...|   1|10/09/2016 23:29|    1|rkJfupaqdSfmeQvVB...|    1|Slowest Canes on ...|     1|mUE0kJRkH-rz6zuCn...|1560000000000|     15|  1.0|
# | 16|bPcqucuuClxYrIM8x...|   0|26/04/2015 16:52|    0|_vaK3rUQfcSXGxaAB...|    5|Fantastic experie...|     0|fGtyech-ku19J6SOT...| 481000000000|     16|  0.0|
# | 17|aqwn3jdQLCWnb59gH...|   0|05/04/2018 22:29|    0|aPKiIxVj-7xMoZ2J3...|    5|We loved the food...|     0|j9rwqrr6xFkCbv7fS...|1530000000000|     17|  0.0|
# | 18|RThuRlhMdowhtY8vI...|   0|10/07/2007 18:21|    0|VzbHYp2CtABZvp7Gp...|    4|One of the best p...|     1|f8cxIBV35TfPVhQDR...| 610000000000|     18|  0.0|
# | 19|xfWdUmrz2ha3rcigy...|   0|24/09/2017 15:26|    0|CVbcShYKD88NxvkMO...|    5|Definitely a grea...|     1|7R4cy2ITjqwrmYvgk...| 215000000000|     19|  0.0|
# +---+--------------------+----+----------------+-----+--------------------+-----+--------------------+------+--------------------+-------------+-------+-----+
# only showing top 20 rows

# %%
#df_dev.schema.names
#df_dev.printSchema()

# %% [markdown]
# ## Create Clean Tokens

# %%
document_assembler = DocumentAssembler() \
            .setInputCol("text")\
            .setOutputCol("document")\
            .setCleanupMode("shrink")

sentence_detector = SentenceDetector() \
    .setInputCols(["document"]) \
    .setOutputCol("sentence")

tokenizer = Tokenizer() \
    .setInputCols(["sentence"]) \
    .setOutputCol("token") \
    #.setSplitChars(['-']) \
   # .setContextChars(['(', ')', '?', '!']) \

normalizer = Normalizer() \
            .setInputCols(["token"]) \
            .setLowercase(True)\
            .setOutputCol("normal")

lemmatizer = LemmatizerModel.pretrained('lemma_antbnc') \
    .setInputCols(["normal"]) \
    .setOutputCol("lemma") \
    #.setDictionary("/tmp/lemmas_small.txt", key_delimiter="->", value_delimiter="\t")

stop_words_cleaner = StopWordsCleaner() \
        .setInputCols(["lemma"]) \
        .setOutputCol("cleanTokens") \
        .setCaseSensitive(False) 

finisher = Finisher() \
    .setInputCols(["cleanTokens"]) \
    .setIncludeMetadata(False)\
    .setOutputCols(["cleanTokens"])

pipeline = Pipeline(stages=[
    document_assembler,
    sentence_detector,
    tokenizer,
    normalizer,
    lemmatizer,
    stop_words_cleaner,
    finisher
])

normalized_data = pipeline.fit(df_dev).transform(df_dev)
normalized_data.show(5)
# Out:
# lemma_antbnc download started this may take some time.
# Approximate size to download 907.6 KB
# [OK!]
# +---+--------------------+----+----------------+-----+--------------------+-----+--------------------+------+--------------------+-------------+-------+-----+--------------------+
# |  #|         business_id|cool|            date|funny|           review_id|stars|                text|useful|             user_id|      index_1|index_2|label|         cleanTokens|
# +---+--------------------+----+----------------+-----+--------------------+-----+--------------------+------+--------------------+-------------+-------+-----+--------------------+
# |  0|XFhnPpO2x0nS-lVkq...|   1|14/02/2017 16:50|    0|o6VZ0cQEfIBvGW15u...|    2|I knew it was a k...|     0|dk5yqirSwDH7Cpp52...|1080000000000|      0|  1.0|[know, kitschy, p...|
# |  1|SRCepG6PbMvwKcfIU...|   0|11/12/2015 02:47|    0|PBy3gB_D1xEiBJDrw...|    2|Average place, bu...|     0|xmtWxX67wF7afssQR...| 730000000000|      1|  1.0|[average, place, ...|
# |  2|pneBBrIzd3SCbbglY...|   2|15/05/2015 19:18|    0|AeyK7AEtbfubw1aD0...|    4|This is a great o...|     4|X4k8ugJaihHVLHq32...| 490000000000|      2|  0.0|[great, outside, ...|
# |  3|8enR8Wc0ot9L41JY1...|   0|15/09/2017 13:17|    0|Vkx4AUppu9A7DL3AI...|    5|We took shelter a...|     0|Xpl0z24sZ-zJ6klgV...|1150000000000|      3|  0.0|[take, shelter, a...|
# |  4|HhVmDybpU7L50Kb5A...|   0|06/02/2016 02:12|    0|2GtcaGkq5nAxBvKZp...|    3|Had the burgers o...|     0|9T39fu4au232kl25R...| 996000000000|      4|  1.0|[burger, carnival...|
# +---+--------------------+----+----------------+-----+--------------------+-----+--------------------+------+--------------------+-------------+-------+-----+--------------------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import concat_ws

normalized_data = normalized_data.withColumn("cleanTokens_n", concat_ws(",", "cleanTokens"))
normalized_data.select('cleanTokens_n').show(truncate=False)
# Out:
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |cleanTokens_n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |know,kitschy,place,find,online,picture,online,match,get,eat,locate,park,lot,front,mall,next,motelhotel,typical,look,outside,usual,jukebox,old,poster,assorted,memorabilia,wall,nobody,dress,like,see,one,ad,service,alright,slow,server,table,plus,table,behind,couple,overwhelm,look,like,lot,snowbirds,go,well,hotel,worker,stop,bite,head,food,reasonable,nice,honest,wish,choose,someplace,else,go,wouldnt,return                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |average,place,wish,wouldve,read,review,order,torta,figure,way,id,never,order,one,ill,give,torta,another,chance                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# |great,outside,poolside,place,delightful,imaginative,drink,locate,wild,horse,pass,resort,spa,chandler,az,also,provide,variety,food,item,satisfy,hunger,fantastic,view,surround,mountain,large,pool,area,adult,child,pool,chair,flag,system,raise,service,matter,sit,never,leave,seat,food,drink,separate,eat,area,cover,bird,beg,food,afraid,human,long,flight,place,sit,back,enjoy,scenery,take,drink,three,staff,good,draw,back,like,place,miami,gratuity,add,check,shame,business,feel,worker,people,leave,little,tip,server,dont,wish,tip,always,fast,food,drive,thru,enjoy,drink,food,especially,staff,host,family,get,together,weekend                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
#
# |  2|pneBBrIzd3SCbbglY...|   2|15/05/2015 19:18|    0|AeyK7AEtbfubw1aD0...|    4|This is a great o...|     4|X4k8ugJaihHVLHq32...| 490000000000|      2|  0.0|[great, outside, ...|great,outside,poo...|
# |  3|8enR8Wc0ot9L41JY1...|   0|15/09/2017 13:17|    0|Vkx4AUppu9A7DL3AI...|    5|We took shelter a...|     0|Xpl0z24sZ-zJ6klgV...|1150000000000|      3|  0.0|[take, shelter, a...|take,shelter,anda...|
# |  4|HhVmDybpU7L50Kb5A...|   0|06/02/2016 02:12|    0|2GtcaGkq5nAxBvKZp...|    3|Had the burgers o...|     0|9T39fu4au232kl25R...| 996000000000|      4|  1.0|[burger, carnival...|burger,carnival,c...|
# +---+--------------------+----+----------------+-----+--------------------+-----+--------------------+------+--------------------+-------------+-------+-----+--------------------+--------------------+
# only showing top 5 rows

# %% [markdown]
# ## Get Number of Tokens

# %%
normalized_data = normalized_data.withColumn('n_clean_tokens', F.expr('size(cleanTokens)'))
normalized_data.show(5)
# Out:
# +---+--------------------+----+----------------+-----+--------------------+-----+--------------------+------+--------------------+-------------+-------+-----+--------------------+--------------------+--------------+
# |  #|         business_id|cool|            date|funny|           review_id|stars|                text|useful|             user_id|      index_1|index_2|label|         cleanTokens|       cleanTokens_n|n_clean_tokens|
# +---+--------------------+----+----------------+-----+--------------------+-----+--------------------+------+--------------------+-------------+-------+-----+--------------------+--------------------+--------------+
# |  0|XFhnPpO2x0nS-lVkq...|   1|14/02/2017 16:50|    0|o6VZ0cQEfIBvGW15u...|    2|I knew it was a k...|     0|dk5yqirSwDH7Cpp52...|1080000000000|      0|  1.0|[know, kitschy, p...|know,kitschy,plac...|            65|
# |  1|SRCepG6PbMvwKcfIU...|   0|11/12/2015 02:47|    0|PBy3gB_D1xEiBJDrw...|    2|Average place, bu...|     0|xmtWxX67wF7afssQR...| 730000000000|      1|  1.0|[average, place, ...|average,place,wis...|            19|
# |  2|pneBBrIzd3SCbbglY...|   2|15/05/2015 19:18|    0|AeyK7AEtbfubw1aD0...|    4|This is a great o...|     4|X4k8ugJaihHVLHq32...| 490000000000|      2|  0.0|[great, outside, ...|great,outside,poo...|           100|
# |  3|8enR8Wc0ot9L41JY1...|   0|15/09/2017 13:17|    0|Vkx4AUppu9A7DL3AI...|    5|We took shelter a...|     0|Xpl0z24sZ-zJ6klgV...|1150000000000|      3|  0.0|[take, shelter, a...|take,shelter,anda...|            46|
# |  4|HhVmDybpU7L50Kb5A...|   0|06/02/2016 02:12|    0|2GtcaGkq5nAxBvKZp...|    3|Had the burgers o...|     0|9T39fu4au232kl25R...| 996000000000|      4|  1.0|[burger, carnival...|burger,carnival,c...|            31|
# +---+--------------------+----+----------------+-----+--------------------+-----+--------------------+------+--------------------+-------------+-------+-----+--------------------+--------------------+--------------+
# only showing top 5 rows

# %%
#normalized_data.select('n_clean_tokens').show()

# %% [markdown]
# ## Get Sentiment per review

# %%
document_assembler = DocumentAssembler() \
    .setInputCol("text")

sentence_detector = SentenceDetector() \
    .setInputCols(["document"]) \
    .setOutputCol("sentence")

tokenizer = Tokenizer() \
    .setInputCols(["sentence"]) \
    .setOutputCol("token")

lemmatizer = LemmatizerModel.pretrained('lemma_antbnc') \
    .setInputCols(["token"]) \
    .setOutputCol("lemma") \
        
sentiment_detector = SentimentDetector() \
    .setInputCols(["lemma", "sentence"]) \
    .setOutputCol("sentiment_score") \
    .setDictionary("./sentiment_lexicon.txt", ",")  #Chen, Y., & Skiena, S. (2014). Building Sentiment Lexicons for All Major Languages. In ACL (2) (pp. 383-389).
    
finisher = Finisher() \
    .setInputCols(["sentiment_score"]) \
    .setOutputCols(["lex_sentiment"])


pipeline = Pipeline(stages=[
    document_assembler,
    sentence_detector,
    tokeniz

# +---+--------------------+----+----------------+-----+--------------------+-----+--------------------+------+--------------------+-------------+-------+-----+--------------------+--------------------+--------------+-------------+
# only showing top 20 rows

# %% [markdown]
# ## Get Sentiment ratio from the sum of all sentences for each review (needs to be fixed)

# %%
###NEEDS TO BE FIXED

pipeline = PretrainedPipeline("analyze_sentiment", lang="en")
sentiment_data = pipeline.annotate(normalized_data, column='text')

from pyspark.sql import functions as F
sentiment_data = sentiment_data.withColumn('pos_cnt', F.expr('size(filter(sentiment.result, x -> x in ("positive")))'))
sentiment_data = sentiment_data.withColumn('neg_cnt', F.expr('size(filter(sentiment.result, x -> x in ("negative")))'))
sentiment_data = sentiment_data.withColumn("pos_prc", sentiment_data["pos_cnt"]/(sentiment_data["pos_cnt"]+sentiment_data["neg_cnt"])).fillna(0)

sentiment_data.show(5)
#sentiment_data.select('sentiment.result').show(5)
# Out:
# analyze_sentiment download started this may take some time.
# Approx size to download 4.9 MB
# [OK!]
# +---+--------------------+----+----------------+-----+--------------------+-----+--------------------+------+--------------------+-------------+-------+-----+--------------------+--------------------+--------------+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+-------+-------+------------------+
# |  #|         business_id|cool|            date|funny|           review_id|stars|                text|useful|             user_id|      index_1|index_2|label|         cleanTokens|       cleanTokens_n|n_clean_tokens|lex_sentiment|            document|            sentence|               token|             checked|           sentiment|pos_cnt|neg_cnt|           pos_prc|
# +---+--------------------+----+----------------+-----+--------------------+-----+--------------------+------+--------------------+-------------+-------+-----+--------------------+--------------------+--------------+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+-------+-------+------------------+
# |  0|XFhnPpO2x0nS-lVkq...|   1|14/02/2017 16:50|    0|o6VZ0cQEfIBvGW15u...|    2|I knew it was a k...|     0|dk5yqirSwDH7Cpp52...|1080000000000|      0|  1.0|[know, kitschy, p...|know,kitschy,plac...|            65|   [positive]|[[document, 0, 78...|[[document, 0, 12...|[[token, 0, 0, I,...|[[token, 0, 0, I,...|[[sentiment, 0, 1...|      6|      3|0.6666666666666666|
# |  1|SRCepG6PbMvwKcfIU...|   0|11/12/2015 02:47|    0|PBy3gB_D1xEiBJDrw...|    2|Average place, bu...|     0|xmtWxX67wF7afssQR...| 730000000000|      1|  1.0|[average, place, ...|average,place,wis...|            19|   [positive]|[[document, 0, 20...|[[document, 0, 78...|[[token, 0, 6, Av...|[[token, 0, 6, Av...|[[sentiment, 0, 7...|      0|      3|               0.0|
# |  2|pneBBrIzd3SCbbglY...|   2|15/05/2015 19:18|    0|AeyK7AEtbfubw1aD0...|    4|This is a great o...|     4|X4k8ugJaihHVLHq32...| 490000000000|      2|  0.0|[great, outside, ...|great,outside,poo...|           100|   [positive]|[[document, 0, 10...|[[document, 0, 76...|[[token, 0, 3, Th...|[[token, 0, 3, Th...|[[sentiment, 0, 7...|      8|      5|0.6153846153846154|
# |  3|8enR8Wc0ot9L41JY1...|   0|15/09/2017 13:17|    0|Vkx4AUppu9A7DL3AI...|    5|We took shelter a...|     0|Xpl0z24sZ-zJ6klgV...|1150000000000|      3|  0.0|[take, shelter, a...|take,shelter,anda...|            46|   [positive]|[[document, 0, 42...|[[document, 0, 48...|[[token, 0, 1, We...|[[token, 0, 1, We...|[[sentiment, 0, 4...|      5|      4|0.5555555555555556|
# |  4|HhVmDybpU7L50Kb5A...|   0|06/02/2016 02:12|    0|2GtcaGkq5nAxBvKZp...|    3|Had the burgers o...|     0|9T39fu4au232kl25R...| 996000000000|      4|  1.0|[burger, carnival...|burger,carnival,c...|            31|   [positive]|[[document, 0, 38...|[[document, 0, 60...|[[token, 0, 2, Ha...|[[token, 0, 2, Ha...|[[sentiment, 0, 6...|      6|      2|              0.75|
# +---+--------------------+----+----------------+-----+--------------------+-----+--------------------+------+--------------------+-------------+-------+-----+--------------------+--------------------+--------------+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+-------+-------+------------------+
# only showing top 5 rows

# %% [markdown]
# ## Snorkle trials

# %%
#Try to apply Labeling function
import pyspark.sql.functions as F
from snorkel.labeling import LabelModel
from snorkel.labeling.apply.spark import SparkLFApplier
import pandas as pd
import numpy as np
#from snorkel.labeling import ,LFAnalysis
from snorkel.labeling import LFAnalysis
from pyspark.sql import Row
from snorkel.labeling.lf import labeling_function
#from snorkel.labeling.lf.nlp_spark import spark_nlp_labeling_function
from snorkel.preprocess import preprocessor

ABSTAIN = -1
NEGATIVE = 0
POSITIVE = 1

# %%
sentiment_data.show(5)
# Out:
# +---+--------------------+----+----------------+-----+--------------------+-----+--------------------+------+--------------------+-------------+-------+-----+--------------------+--------------------+--------------+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+-------+-------+------------------+
# |  #|         business_id|cool|            date|funny|           review_id|stars|                text|useful|             user_id|      index_1|index_2|label|         cleanTokens|       cleanTokens_n|n_clean_tokens|lex_sentiment|            document|            sentence|               token|             checked|           sentiment|pos_cnt|neg_cnt|           pos_prc|
# +---+--------------------+----+----------------+-----+--------------------+-----+--------------------+------+--------------------+-------------+-------+-----+--------------------+--------------------+--------------+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+-------+-------+------------------+
# |  0|XFhnPpO2x0nS-lVkq...|   1|14/02/2017 16:50|    0|o6VZ0cQEfIBvGW15u...|    2|I knew it was a k...|     0|dk5yqirSwDH7Cpp52...|1080000000000|      0|  1.0|[know, kitschy, p...|know,kitschy,plac...|            65|   [positive]|[[document, 0, 78...|[[document, 0, 12...|[[token, 0, 0, I,...|[[token, 0, 0, I,...|[[sentiment, 0, 1...|      6|      3|0.6666666666666666|
# |  1|SRCepG6PbMvwKcfIU...|   0|11/12/2015 02:47|    0|PBy3gB_D1xEiBJDrw...|    2|Average place, bu...|     0|xmtWxX67wF7afssQR...| 730000000000|      1|  1.0|[average, place, ...|average,place,wis...|            19|   [positive]|[[document, 0, 20...|[[document, 0, 78...|[[token, 0, 6, Av...|[[token, 0, 6, Av...|[[sentiment, 0, 7...|      0|      3|               0.0|
# |  2|pneBBrIzd3SCbbglY...|   2|15/05/2015 19:18|    0|AeyK7AEtbfubw1aD0...|    4|This is a great o...|     4|X4k8ugJaihHVLHq32...| 490000000000|      2|  0.0|[great, outside, ...|great,outside,poo...|           100|   [positive]|[[document, 0, 10...|[[document, 0, 76...|[[token, 0, 3, Th...|[[token, 0, 3, Th...|[[sentiment, 0, 7...|      8|      5|0.6153846153846154|
# |  3|8enR8Wc0ot9L41JY1...|   0|15/09/2017 13:17|    0|Vkx4AUppu9A7DL3AI...|    5|We took shelter a...|     0|Xpl0z24sZ-zJ6klgV...|1150000000000|      3|  0.0|[take, shelter, a...|take,shelter,anda...|            46|   [positive]|[[document, 0, 42...|[[document, 0, 48...|[[token, 0, 1, We...|[[token, 0, 1, We...|[[sentiment, 0, 4...|      5|      4|0.5555555555555556|
# |  4|HhVmDybpU7L50Kb5A...|   0|06/02/2016 02:12|    0|2GtcaGkq5nAxBvKZp...|    3|Had the burgers o...|     0|9T39fu4au232kl25R...| 996000000000|      4|  1.0|[burger, carnival...|burger,carnival,c...|            31|   [positive]|[[document, 0, 38...|[[document, 0, 60...|[[token, 0, 2, Ha...|[[token, 0, 2, Ha...|[[sentiment, 0, 6...|      6|      2|              0.75|
# +---+--------------------+----+----------------+-----+--------------------+-----+--------------------+------+--------------------+-------------+-------+-----+--------------------+--------------------+--------------+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+-------+-------+------------------+
# only showing top 5 rows

# %%
sentiment_data.select(sentiment_data.lex_sentiment[0]).show(5)
# Out:
# +----------------+
# |lex_sentiment[0]|
# +----------------+
# |        positive|
# |        positive|
# |        positive|
# |        positive|
# |        positive|
# +----------------+
# only showing top 5 rows

# %%
from snorkel.labeling import LabelingFunction


@labeling_function()
def short_comment(x):
    """Negative comments are often short, such as 'foods were insane'"""
    return NEGATIVE if x.n_clean_tokens < 50 else ABSTAIN

@labeling_function()
def keyword_disgusting(x):
    """Negative comments are often short, such as 'foods were insane'"""
    return POSITIVE if x.lex_sentiment[0]=='positive' else ABSTAIN

# %%
lfs = [short_comment,keyword_disgusting]
applier = SparkLFApplier(lfs)
L_dev = applier.apply(sentiment_data.rdd)
g_label =np.array(sentiment_data.select('label').collect())
LFAnalysis(L_dev, lfs).lf_summary(g_label)
# Out:
#                     j Polarity  Coverage  Overlaps  Conflicts  Correct  \
# short_comment       0      [0]      0.61     0.544      0.544      195
# keyword_disgusting  1      [1]      0.89     0.544      0.544      166
#
#                     Incorrect  Emp. Acc.
# short_comment             110   0.639344
# keyword_disgusting        279   0.373034

# %% [markdown]
# ## appendix

# %%
#get business_id
#df_dev.select('business_id').rdd.flatMap(lambda x: x).collect()
# Out:
# ['XFhnPpO2x0nS-lVkqZSf_Q',
#  'SRCepG6PbMvwKcfIUjk8bQ',
#  'pneBBrIzd3SCbbglYRTBZA',
#  '8enR8Wc0ot9L41JY1FxMlA',
#  'HhVmDybpU7L50Kb5A0jXTg',
#  'LUDX--wfStrKavGyitk4nA',
#  'AED5R0yXVzJvWAGEqWBG4A',
#  'cxsN3mkioAXuOLKy04QpyA',
#  'vfwTrfrZ3FWhVkyLjAggLQ',
#  'dsYjWjV0vr1RgSJ78B7K1w',
#  'Jm_R0IhwFlfCAV3Fk6NTWg',
#  'WFB1fn8rWNukmmIfTg6AMw',
#  'qQXc9D6PV1Y8RhIBZpj-Jg',
#  'xiWmyJyTa7o1H6uUNH2dEw',
#  'ZAuAwz1ijuydn5yL3q3rzA',
#  'TT2bNjvnVNFOanDNYnAffQ',
#  'bPcqucuuClxYrIM8xWoArg',
#  'aqwn3jdQLCWnb59gHK4nAw',
#  'RThuRlhMdowhtY8vITEIzQ',
#  'xfWdUmrz2ha3rcigyITV0g',
#  'F1PMcEIg-FHZvwhiUoFEgw',
#  '4g7vpvqPMgWGwge1w5JSAA',
#  'fI9ErCUGY8rXRPBbatcxMA',
#  'iag4htR8F7FmE9zpz7_GMw',
#  'yxdmX8dXk5Se9zJ4WAW1pw',
#  '5shgJB7a-2_gdnzc0gsOtg',
#  '3oajqiPFhYQJsHHiVCchEQ',
#  'BedDWXrINOyEjP8NTXoQ-Q',
#  'ApHiz1xxENwjkp8MKrE4Dg',
#  'NblDoJBEwhkJyvAuxzh4rg',
#  '3Jq5LfJ5fmJ5KmuA6VHmzw',
#  'zaLFPpm-t89qSDOaFVgwDQ',
#  'rq5dgoksPHkJwJNQKlGQ7w',
#  'GQ5f1D9CbFLXkBAlGR7riA',
#  'F3oDNZGUJBIHHy4wQ5jRGw',
#  '1qwkbN3wu3AGDxMTXVz2gA',
#  'CdpBVSkL2Pljj-yP0ihb_w',
#  'Y-S2LhHefBdnX8VP5Bh_JA',
#  'dC60NKVSKNMaymlp_5wuyw',
#  'U6P56MjLrraN0JBNvOjxaA',
#  'cs1qJvnWUg_f8g020z_3PQ',
#  'AUOlDSQ8R2wIkN4lQ4kVDg',
#  'BEXk74R0Icp-Osys_qRiRw',
#  'QJR4qBUHegWEozSQrGmBPw',
#  'OJaODLWh3YtZPK5V5L_CnQ',
#  'XlZ2Row0pszDilc5WmXiZQ',
#  '9Q1ZtzTPFWG4fJiFSko5Xg',
#  'EZ4TljJvGenxrkM4JsqtZg',
#  'MtzjOi57BkQrqF8wqNOyHg',
#  'u-SJ5QUwrNquL9VnXwl8cg',
#  '0WhxNqfHfiuolkcrCo-JHQ',
#  '1d6c6Q2j2jwVzBfX_dLHlg',
#  'fQwB9Z98YEhkJit7c3z51A',
#  '77h11eWv6HKJAgojLx8G4w',
#  'QJatAcxYgK1Zp9BRZMAx7g',
#  '2iTsRqUsPGRH1li1WVRvKQ',
#  'hQeS3VtQD7UDzl-qvW_AfQ',
#  'b6maj_RSR-UKipl7QFXypA',
#  'ypfFfR3-PbtoslIhohNstw',
#  '61Sh8bq29FgrggAhs7sSnQ',
#  'rLwxan_oYkL-m8ldqsHuiA',
#  'VsRAIb4k5CjEF-3l_bac0g',
#  '8klKfy9tK0ySi1l_ajOR5w',
#  '5vgieFiCubi43G6ciiFhNQ',
#  'x1ClWF6HF3X_7TFFnLED_Q',
#  'oN_A87dyVD2FBk7coLnhCg',
#  'U3kygJOTlTQFlfaZS7sQjA',
#  'H5Y6o9H4rtxbHJFgLqI6Fw',
#  'YvrylyuWgbP90RgMqZQVnQ',
#  'SgoPKzmU5CjuD5ewuoJ7oQ',
#  'PwpSY0vO3XlQXKOuqiqZMQ',
#  '0ldxjei8v4q95fApIei3Lg',
#  'Zrx25j1M794Nh8fUGB8E9A',
#  'yYL95YmG-2lI33G9ZLseyQ',
#  'q3oJ6bNRV3OoJrwc95GOwg',
#  'ftCJt8K8T8NV92v-akKo_w',
#  '8XZ4X5WUyM1sWscObramwQ',
#  'u9a_nThKXoF3X5E3xWgnAA',
#  'KX0Dt0CcPdWrSn6ThJ-6Lw',
#  'XFXkImvmUFUERCuZeiuZtw',
#  'zjwdU1OdlbKTGjm-IfD4TQ',
#  'DkZuVzYuylBanEsWK7mNGw',
#  'Y5CTA3S9TVkpr3Yvwaki-A',
#  'fdxyed9ej2LZReHMbESIjA',
#  'dAmVTQ6ukuLh4UxTmBoRkg',
#  'mmazCP1ZH0QsUqDS6OivFA',
#  'GrJ74hxJsXXwcqS7zcfFhw',
#  '0W4lkclzZThpx3V65bVgig',
#  'kkD0tv_e5E6a8kRpLYEcaA',
#  'I4sn_9Nx5KTrMTKaDADQ_Q',
#  'q68NkgNFy8MmM3ZAWZa2PA',
#  'SGpCV9O5teB-we8XNNlGHQ',
#  'ttuEwktrkmh3TUlSFPZqAA',
#  'oxv2UyI5yF6yawPU20tOxA',
#  'ii8sAGBexBOJoYRFafF9XQ',
#  'QlJztL2aGEXgejgi5JM9Xg',
#  'R68SX1-FFLvv6BqsK9-Alw',
#  '0PFf3RKtDQyHnrdcPo8zMQ',
#  'GtSNTE2qMOZBlj0noCgCGw',
#  'Wag4bnx38zJ4ihDn8-7--A',
#  'xk-fOf_M39kDTgzfVgu0Tw',
#  'lEgKurgXzZaMpExXtvBY7w',
#  '0gWg-kqRLEQbhui8b_v2Xw',
#  'IdLzooqPyvEtP_rv2eR6pQ',
#  'R_ZlcX46pPdjhjmfd043LA',
#  'X2X3n0PutSNonQQj2cjsCw',
#  'gkIyPrNGpF4EGqoYWe2KBQ',
#  'EtFtF_FPvqpeTlbj9zFfmA',
#  'NC8Eo3rPaBMd3Ja4FdLnLg',
#  'F2Ic0wqZkWz2cSwSWkJ5mA',
#  'nZnebnuZDiBJxEMDxcDF-w',
#  '_9vGmNrEcLWFOnUzeUdfag',
#  'sjxNnjKwWn7H6QcsAhhXww',
#  'K6Q4jshtcZZg6giPn5NQLw',
#  'XNboW0mRBApLxIzoXvhHNA',
#  'byX9dKMcLA1CDdf3UeHDFg',
#  'NXT94mdw1KWadc3q0u0KYg',
#  'j9cVHTAIkliYQp4XoVcsnQ',
#  'oFBbCtYE_BvuCMsH-yGNJQ',
#  '1JpfQCgLnmz6VU00O1XIPw',
#  'HJ928N6c5Hh2KD3lYCuabA',
#  'fuW-VCynECpKukrm-9nxdg',
#  'N0apJkxIem2E8irTBRKnHw',
#  'JcWzvvDWh4RY04tvm1LQzA',
#  'C_VoO9M9Kuhn6EObmpvWow',
#  'IRzXVRIzRoYpnjaVXF3vNA',
#  'eMKqAItLbazgUT8xokz7fw',
#  'mDR12Hafvr84ctpsV6YLag',
#  'cxsN3mkioAXuOLKy04QpyA',
#  'n_o2DAmDBAZ-RjVDSY-5uQ',
#  'S37sKRRfkhFZRpxaYzWo_A',
#  'JQLi-Ow9pg391iMzw5LSwg',
#  'vyeQzjZFx6KoL2pJBQ2QFA',
#  'rwLm3556i3xw2n3ND0cpdg',
#  '7g03Bv-yYVJHzMD_YKqBQg',
#  'kROYR_6mVfg9WgJ7z1HOSA',
#  'JU2K7-ZmLZWc43ASTs7T1Q',
#  'GjX2WgchvvS-JAWBmzkLyQ',
#  '#NAME?',
#  'RtUvSWO_UZ8V3Wpj0n077w',
#  'LeU2bXqL4bWlky4z4PPysw',
#  'GJ_bXUPv672YwNg4TneJog',
#  'CuT2Xh3vAYvRfxUWlUo6oA',
#  'CESgogUugOYph4p12qvzFg',
#  'm1Y47fK3vWCJXV3TdCn_Xw',
#  'QuybD_bJcAB2CHcpTfREYg',
#  '2zx0Pt5OeHhjAZoNRqYTog',
#  'PglC8rgguMIlT621p1BLdQ',
#  'r6apfvgfl9lCFEjpnXnnxg',
#  'umxN12ok_qOB4qru0qmx6g',
#  '3C5Z9homtzkWHouH2BHXYQ',
#  'Ufo0Papm3oyoCfBvnsJH7g',
#  '3GEEy7RP6e4bT4LAiWFMFQ',
#  '#NAME?',
#  'RcB7STNxoSDjtoK1pXgWBg',
#  'Ol4QM1QI5GlK36t2sGC7KA',
#  'qK9Ap-_B_Nof_WwockrVCw',
#  'el-3IdlW3bTCSnquLvH-3w',
#  '0GS6_96ld7mdEfgKhoDliA',
#  'FwuSvfRx_xkWV61VnCy9ug',
#  'ddlnpDxGDDxGGoG_dVXwiw',
#  'kPfhSK0kcUmOTmC5DEjaDw',
#  '1AxEmgv8Dsr3iU9Aa40jPw',
#  'MpovsyjkSkchD7ssAdEVKQ',
#  'pJnN5PxqFPGZW2pJWkQtzA',
#  'ZOAid_xX3q85wAkBWtFDPg',
#  'ITOa1olD2HTgEVOnH8zVog',
#  'SxvKjtbq5qRlFoXrU8Bo9Q',
#  '#NAME?',
#  'g-kRq6VKB5ld00OOpJvaTg',
#  'cYwJA2A6I12KNkm2rtXd5g',
#  'Ls1NqcogI-szYoQ7tLh4Og',
#  '_MVSmAYSl4RkgXBg5e8JaQ',
#  'JwXNyXdJmk_YnXokLhpI8w',
#  'Rv1IiQaIIDunqzS8dSvHCw',
#  'W2CzAePJakvARgoQuohbOA',
#  'AVqjAx6j4HAvUb8t3_lv8Q',
#  '2SfSzEd3B7WimeZac23zhg',
#  'VMr8sgoQOW0fo0qVJENajA',
#  'f4x1YBxkLrZg652xt2KR5g',
#  '8mIrX_LrOnAqWsB5JrOojQ',
#  'vHz2RLtfUMVRPFmd7VBEHA',
#  'gQnCTgwNFHfB40c8NoGAlw',
#  'ewEDv_q-K0fV0FepkHB8sA',
#  'XD0LjNuPPwJPsTAHecUh7A',
#  'eS29S_06lvsDW04wVrIVxg',
#  'L-aDFoHDcVG1ImCoG361jw',
#  '_k-GxjmoJYelsGHA5NIPiQ',
#  'ZU4sZ0_PB918bK9h6z9l0w',
#  '#NAME?',
#  'k7Sy557_ZaQSGHFlZgeJzw',
#  'rdE9gg0WB7Z8kRytIMSapg',
#  'ugLqbAvBdRDc-gS4hpslXw',
#  'hHtOsr-NMviBKlMqDBeI9Q',
#  'INzLc1Y0JNQzIHjPH2Nbeg',
#  '4xnVH2jTVwrsO88q_jHWWw',
#  '4JNXUYY8wbaaDmk3BPzlWw',
#  'UJevx59U-bi6fRADCSa7LQ',
#  'zB4TOI3Ci9BOidw55TREbA',
#  'e2zO5THDYoDOcyXcWnQv5w',
#  '5gu96LoZOM6Sres5yMQLHA',
#  '9WMBTUjzDFZf2KcBqNc2xw',
#  'bK5nWi1oNs63utSlzmRUNg',
#  '522GgMvOvzaKCEX6BfAtvg',
#  'jaSowNITPRRCYpPb3_pjdA',
#  'eYJcI9cI6-kJ2NQpYdHcLw',
#  'fW7SHgmidc32kHSoyLTM2A',
#  'HxfrVqxnsFI7MByNI7QINg',
#  'eJPckkV1k7gn0V2awA1pzA',
#  'bFzFGDQTLsAs1WKA_EGjZA',
#  'xCmFGgpTkf77fNCrvkDBsA',
#  'YJlVKAH80iptMCsN6TZevA',
#  '7ra_3K_ZebXNjMpaC6yVow',
#  '9yESUcIVarhYEabIMj844Q',
#  '4BZwZrm3atfkDkc0gV3sCQ',
#  'hdnrqrYJE1RkoUH4MFq3Ag',
#  '6JTxM3pZAaiauddFu88VpA',
#  '7cK9uEV09iPmsTqOqmY3kQ',
#  'hRQS8y-uG2kc8miWVYiLuQ',
#  'O1TvPrgkK2bUo5O5aSZ7lw',
#  'Qor28v4BlhSwtN8DSvah9g',
#  'SwAZBCyFtVo_8vkRbJhdkA',
#  'Yf74t_bR1mhRXY03IU6OhA',
#  'O-uIEuv7JLUHajkemx_sVw',
#  'zWOFKsBDFTYfU4Mp6lONTA',
#  'stk0K_Tx5ncnIutqrd2nqg',
#  'sl5ak_xmGQmk7pYEIw5cEA',
#  'jhCcZgDhPh5oiPgOXYTkrg',
#  '5-_4mHujcNo0PWj3-ybwnQ',
#  '6H8xfhoZ2IGa3eNiY5FqLA',
#  'yfxDa8RFOvJPQh0rNtakHA',
#  'nsY7J0cdi6usTTswuy8hSA',
#  'MdS6EHt2RZFpn9fQXZc9Ig',
#  'KBWLCfWyfoXMvvBOXlABlw',
#  'RhEvP5flF6KoPriMHmVYGg',
#  'HwjhWHbNp56t-dRiv3-wPA',
#  'h2vFVV5pJjn8arA7GR6mQg',
#  '65eDIQ8bpMJFtgdyX7ulVA',
#  'LGEIsxeJQATo9J1IA-TEdA',
#  'j2bx_ctb_ED3zbfSaqhQmQ',
#  'xVEtGucSRLk5pxxN0t4i6g',
#  'NXT94mdw1KWadc3q0u0KYg',
#  'K_xtAppJIWWeO8pNzK22lA',
#  'xU_QqrlaxXlf2SKoNIaGpg',
#  '3GEEy7RP6e4bT4LAiWFMFQ',
#  'M30I1NPl5JuHthxo1IXPGg',
#  'Ja4stXdNYr39u5CZHMNtjw',
#  'tH_ObhULoHCb1n08pbHgHQ',
#  '1ZJz840L496LAmQdeDv0WA',
#  'K7lWdNUhCbcnEvI0NhGewg',
#  'HiHUTSxpyKhQqLFti3Xnzw',
#  'eAc9Vd6loOgRQolMXQt6FA',
#  'tcnu9ivUsuQUNiz944bpOA',
#  'xAg2w4pxJURbB2edAg2wMQ',
#  'UESdOMLsXn_7WcwOZt7I3A',
#  'np8wj1g3cgCoIcJ26zozpA',
#  '_euNvs0P14284FXN1vZ_Pw',
#  'ZHQU79PMUGCX0fEoyCcWlw',
#  'qVbZ_VrZEGJKJg9ZpkGzjw',
#  'Ho90V3P89bUtKpr93y-15g',
#  'Pthe4qk5xh4n-ef-9bvMSg',
#  'wUKzaS1MHg94RGM6z8u9mw',
#  'cxA-ETXXXBzOlR83j7feMQ',
#  'S8urdN6ACnRQUm-7o9An8w',
#  '5shgJB7a-2_gdnzc0gsOtg',
#  'sLKpRaFns5Uqw1IEzK6obA',
#  '67zCgILB2h6JoSvFabVe7g',
#  '8Cny1-SYxd8vtgmBFFSJYA',
#  'YkAcruXbhN6sHDXn0jcySw',
#  'V90fC_aF-_DNYzQvUtbLww',
#  'Nrpu_v4KqQhdnWlVbPjiiA',
#  '698nukvxe7mq2Fra5vDikQ',
#  'PRbIMseOwPCCRv5C4SfTDQ',
#  'X4YG1pu1MDVSi07S3i4YCA',
#  'h6JacIFzb9jxFpKpgsGuuQ',
#  'e7bcP2P8WO0NFe1DjjoYQA',
#  'IE0QRqaUSW51RmShZ9dX1Q',
#  'dn51F67VLgPuqy_8SFk9oA',
#  'UUtWoDyREiy9MPdtTRFUYQ',
#  'HdE4WIo1AC9ZRDq7I0ZB5g',
#  'umrDQGRNied77aVg29_fVw',
#  'UqhVZYUeoBGroYpZB-9jlQ',
#  'UFn1moo95-PBzi9wWt5FGg',
#  '64dfRmMmUsOdLnkBOtzp4w',
#  '0P46EQN6wGc52nONZX0kgQ',
#  'Jv5NmXlB3XuLR3yk7B8amw',
#  'lMx29wnA8FxJMcDoME_VoQ',
#  't43tq66jU-sLXA-TVgKxrg',
#  'eAc9Vd6loOgRQolMXQt6FA',
#  'oN8HDF_cPDaeFB69yC6I5A',
#  'L2p0vO3fsS2LC6hhQo3CzA',
#  'ee8aiHC6zaY9JoLUVUSc1w',
#  '#NAME?',
#  'SWhHaWFuijy_KDs0zVCJog',
#  'TkEMlu88OZn9TKZyeY9CJg',
#  'VyVIneSU7XAWgMBllI6LnQ',
#  'g8OnV26ywJlZpezdBnOWUQ',
#  '0Mp_0j2dfMXE6l-3Raqorg',
#  '9aYmWMneDv9huo9140VJfw',
#  'kiBOT50alvcwdwUk6Wc1Rw',
#  'hPXR-Bi8U-uz6TUViqmGpg',
#  'I6EDDi4-Eq_XlFghcDCUhw',
#  'SrIlbndBJKTJcWNF-fLP7Q',
#  'zDKH2ua2DauqiWOAP9yz7g',
#  'bI9_dtXS9qN0Gmi7YbRm5g',
#  '0go_co5nVtlbu4HgUyUIOQ',
#  'i4EMu1nCDfgF6CB0MKOUzw',
#  'J4WxIqKaKSGNjtxTBPhLBQ',
#  'hDy-uY7Vy_TZdGBzw59lhA',
#  'eh127ASMZstrELE0K0XADw',
#  '330HJ6PP0faybQt5u95kTQ',
#  'K7lWdNUhCbcnEvI0NhGewg',
#  'WOz66UuVsfc2K9GxzfDnGg',
#  '7eQoxWr9RzyCB9IFvqHUPA',
#  'yDk_gqG_h24zqu4dGp6Mkw',
#  '749lGtWM9PsrWonlVY4W2w',
#  'l0v1AdiwMIEP0zpcSmxm1Q',
#  'ni4ppUp4oHq-OSSCgUIGiA',
#  'dtQ_nIADFp7AP91H0ttAKA',
#  'e7byM17cm_J9ulGHD7Fbdw',
#  'SuRxV4YkPsvyyqK57On0rQ',
#  'Hrbwae-MS_7JlS27uoigIA',
#  'cTZmf7B-4yciMc1WKiCVOA',
#  'AaLvYFsLuyO1uGk0QLxN5A',
#  'CrPm7Rby304RmpFgmIBdUQ',
#  'IZivKqtHyz4-ts8KsnvMrA',
#  'KVqWA98XZwGhJ3YbFNi0vw',
#  '423AAbu0yBoDMOeVwnLzkQ',
#  'mnn--vaYHtNyBNYFYBFIog',
#  'w1S46TdjMdQj-zCZoXPd4Q',
#  'P3ufH0wm0jvulnrinDpaAA',
#  'y1H7Q7rN9JmySXvwDVYD8A',
#  '6pQ1DpZo6zygNc3qTch-iA',
#  'z6-reuC5BYf_Rth9gMBfgQ',
#  'anzCdD5eIEHwydTpXhLlUA',
#  'RsQdAT-eFwWpzy0t2SiReQ',
#  'YohEZMYpKrf-3fyPASKLew',
#  'qUWqjjjfpB2-4P3He5rsKw',
#  'wKA2y-F_fPcBDOkpzDB9eQ',
#  'K-uQkfSUTwu5LIwPB4b_vg',
#  'g8OnV26ywJlZpezdBnOWUQ',
#  'n72smZw1iVORdnjGfFT0FQ',
#  'zJGtD3y-pAIGNId4codEEg',
#  '8bib49DjADw9GxQJNydafg',
#  '2weQS-RnoOBhb1KsHKyoSQ',
#  'OAMF8Dlk8OwfGG_1HP2ZRw',
#  'TkoyGi8J7YFjA6SbaRzrxg',
#  'GZONBn0K1yp2aaD-l8debQ',
#  '1qwkbN3wu3AGDxMTXVz2gA',
#  'bKxKPGmkwH-Q-GSbt7chNA',
#  'q3oJ6bNRV3OoJrwc95GOwg',
#  'Bo3dqwrjRbGFDf3S59HzDQ',
#  '9dqdzRzjSfbnMvjUGqWBAw',
#  'pSMK_FtULKiU-iuh7SMKwg',
#  'raHgmWxE8AVSivo92GX5Wg',
#  '5k8kyvvReTf1RMq4jpayQg',
#  'bFNqF_yGq0vvMfmMF04EJg',
#  'KNOuvGb2HoeWnyxSOIYyHg',
#  'GDpd9KZdUgnjcoCWTTphqw',
#  'D4BWyStFZzA7k8hqDmnyFw',
#  'uKKNw68mZZaa1jcyszEbyA',
#  'kXl44keW3wZaJpjEqHk30g',
#  'Y1x-DOdfvlIGxVzDXmd-eg',
#  'oEQLrtyssOdCz96A7QkDkg',
#  'xfWdUmrz2ha3rcigyITV0g',
#  'tTEtAzGbydufWtgOqCMquA',
#  '4JNXUYY8wbaaDmk3BPzlWw',
#  'yNVcnSaMSrTmjJBMrHTy9w',
#  'DZwR0EIPKlmC3mMLhTkqcQ',
#  'iCQpiavjjPzJ5_3gPD5Ebg',
#  'aAkoJKozYZEyBx58wQ-UrQ',
#  'qzjMO-bLXirGU1Q4_8vJEg',
#  'IQLnLQYcTwCjwt_ri9dqhA',
#  'KalAJyO0Zpg3K1wVwYXBHA',
#  'y14TQfHRL5Gkk-CorcR6bg',
#  'lvv9Vv_5i4IwvDdofO_rKg',
#  'VaQhUU3P4Z5A3oYPsEMbkw',
#  'XhUec_6-kgPy1_ZYUrzvPQ',
#  'mnwRtuVQEsIUomBchu0gwg',
#  'hU7z5Jtl57RIODS0hPg9Ug',
#  '5shgJB7a-2_gdnzc0gsOtg',
#  'bSY97kgQpJ5BrpgW40V1qg',
#  'jOJaJatp88cqnkVo8D8RJg',
#  'whAwdYVty-jSNRhrYT2zHA',
#  '7sPNbCx7vGAaH7SbNPZ6oA',
#  'qABb9Wzdn51VcNHdp_Qhpg',
#  'bs07-hLuz0dq06gIUwR5mw',
#  '8YG7PRoZuHeKii0rtNvJFQ',
#  '3ViGD_AF1AUmxF4zeHB_kQ',
#  'KQEuEJ80wwPqhRNSI3em4A',
#  'qO6CWdRFfbOqDJ2UOulpaA',
#  '4JNXUYY8wbaaDmk3BPzlWw',
#  '74gDxr6rs_8tUTcS1vkr0Q',
#  'WWyiaVsJusbRRdpTP5gomQ',
#  'zwmps5SXn30g-f5wqg_r9A',
#  'kBAsDEH8iQ5Gzj5kQiy2_w',
#  'mOMeDQB8NjdBTTzKtikAYg',
#  'lgdde-A-rnzOw9ybmL82pQ',
#  'eJKnymd0BywNPrJw1IuXVw',
#  'vOY6w1Q45Iod8sy2c8zetg',
#  'CiYLq33nAyghFkUR15pP-Q',
#  'vodVvMALuQPScQJpLhfcyg',
#  'TvhpG74DvdoF4MA0vLlOLw',
#  'vUYz-JgVTAtUGUbQuF7czw',
#  'sPd3E7lFzd_yooiq-ekxtQ',
#  'KgbCvPJpFLN78VVkeJMbzw',
#  'Vs7gc9EE3k9wARuUcN9piA',
#  'WR2J_AufGGdPrJobNb5GHw',
#  'ymsa3ReIbctz4IFmPUgWDA',
#  'Y-j6rMW97usezKAs9Usuew',
#  'medCzwjjGeReqxOt-iPVTg',
#  'rnvNY3QmFoOMDEhG535JIQ',
#  'iGEvDk6hsizigmXhDKs2Vg',
#  'Yl05MqCs9xRzrJFkGWLpgA',
#  '51Z3PiEHCeHliT19EO-lVg',
#  '#NAME?',
#  'g8OnV26ywJlZpezdBnOWUQ',
#  'xqMzRiPK2SkN9upGukPzYw',
#  'ElWzx5_fU8S2G45OnM-HpA',
#  'VFrSIKxEQvgNowJ0PJxUzA',
#  'wuQDMDlqM17jQNo0lYQZ7g',
#  'xGF-FT_Ii8bW8JwUCD_0vQ',
#  '5LPK0LeKiS4HKzYwKXvFLg',
#  'FZpyIiCAsr7Twkw4tQeqPA',
#  'dzKDFiWLkspVBJKGfT0M2g',
#  'z2CVPfaG8C_rydUZCcsqbw',
#  '9Eghhu_LzEJgDKNgisf3rg',
#  'iwzVhM5CirzkNS5wTxwZeA',
#  'gc78dwGe4EP6resjJHJEbA',
#  'w_UCGMgok7N9p0XdYBx1VQ',
#  '5pMNyj77S1P3rrT69y1pkQ',
#  'LrO_Xy6lfpbTgFoJcOjY4w',
#  'qkyCuFJF2Uboh6n2Lmuwlg',
#  'siVUkho_c5BaptuWV-_eTg',
#  'Vs6kbMEE557woabfeJ9-qw',
#  'GuvbQ3bCMw6xfUfCQ8N1LA',
#  '75HVFV2yYaaz0qH_KCgyFQ',
#  'sr0rCMn-XtKATvl9adYQxA',
#  '3QQEc5QUP-h6LCkUZQEYQw',
#  'r5pBbEFHWxlBBHs3N8QiPA',
#  'hDDh3dtuFZyty5KOUN0JmA',
#  '35Z23ZztQCsJdASRbU69Vg',
#  'R3TC2oq8fQK9c9BNMZ-ynA',
#  'NblDoJBEwhkJyvAuxzh4rg',
#  'kpLt4l5J5kbMD4oxQLC2aA',
#  'DkZuVzYuylBanEsWK7mNGw',
#  'BIqsItY0vyOshMpJ0I4cPg',
#  '4GXII-GU7S0ZyU6ElkhscQ',
#  'PxKJTQYsiy4cFKPX_GmCwQ',
#  'k9wv5-0u8q4S75MIaTX6aA',
#  'AercPW1B2YVNK3UsiPDkTg',
#  'grzKamxEuXTZrTkiztLQGg',
#  'YTCCJ3ShO-zg0dlx1nk6dw',
#  'ViErpcikhbAjsDcpdAfwSQ',
#  'fbKoXozkAKDxoWg8eyQk9Q',
#  '2Cmpz9lgr-wfOLAwgUf79g',
#  'FYa3GUro-ezTM9zvKiocFw',
#  '2iTsRqUsPGRH1li1WVRvKQ',
#  'jrFB2o5Gk2aRw22oNGxJKg',
#  'D-2t7fHQu6hNLjjfRHSZaA',
#  'xdD3EXvF_p9WUiwwKpol_w',
#  '7ibuDLfx8gEhESAufYIySw',
#  '8RGoNUEC4QGbpF4af7CDdQ',
#  'W035pMPJuocijd0BLfHaiw',
#  'LGOnnrjU50YtT066RP_J3g',
#  'RVNxhRf8ERTAb38vBWvCig',
#  'yfxDa8RFOvJPQh0rNtakHA',
#  '2i0dDzxLuQQAwzxDZVR-1g',
#  'T2tEMLpTeSMxLKpxwFdS3g',
#  'dd3GZs6zW2t7BM0cbxAzvg',
#  'qmIHO-6T_KEfPC9jyGDamQ',
#  'KkmPDIWzvwbBpyqOHT6pcQ',
#  'aKEEQqL1UFMieilnylI1gw',
#  '-6tvduBzjLI1ISfs3F_qTg',
#  'GmdujALb1Nq2RHGr7jhCaA',
#  'LwQB9H3jZ9wTk24Lr-AnZQ',
#  'rGCDSZczGBSdLN9wiz0iXw',
#  'v8qw502wtQEGpQfMhCVW9w',
#  'Sy75QB18Sv-xNp8FoA8KvQ',
#  'nRZjrWIzqKc26KjpBG0fHg',
#  'HI56ArpYEbhEUeRx9Curpw',
#  '#NAME?',
#  'eDdhZZBHEi-TRWQ2xhRI5g',
#  'JIETwXSEGIHMNyxZVEnNKQ',
#  '_6agShdUe17ftw_xHo26IA',
#  'FMnH5WIRLyexBYMBUUnDxQ',
#  '2KWkeOk1KaH50Es_A-8cnA',
#  'U3-kxz7NWq4ix4bPmKKQ0w',
#  '806kkDGaRCJ4lZLRcEf-iw',
#  'zdE82PiD6wquvjYLyhOJNA',
#  '2zo1Gg_ERRjn5LzX9hzR5w',
#  'scM6rLQqoz5dEIgwz_JFsg',
#  'O0DxNujKaN-KIfcgbV3MgA',
#  'pTJ8f4AfUW6uwKGdawLcfg',
#  'tstimHoMcYbkSC4eBA1wEg',
#  'iAxsnFs3qq0Qx1EJ1S9SoQ',
#  'PLUdxLiRUSQQfdcHPq2-Zw',
#  'crstB-H5rOfbXhV8pX0e6g',
#  'p4qvXkb34X8hgidxEZ33Gw',
#  'PVTfzxu7of57zo1jZwEzkg']
